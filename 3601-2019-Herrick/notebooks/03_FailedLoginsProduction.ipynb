# %%
import os
import sys

from sascyber.utils.log import setup_logging
from sascyber.configs.analyticmanager import AnalyticsManagerConfig
from sascyber.servers.DAGServer import DAGServer
from sascyber.utils.exceptions import SASCyberMissingEnvVariable
from sascyber.utils.exceptions import SASCyberMissingConfig

# %%
from sascyber.analytics.wh.logins import Logins

# %%
os.environ["CYBER_ARGS"] = '/home/ds/custom/config/wh_60m.json'
os.environ["CYBER_ROOT"] = '/home/ds'
os.environ["CYBER_DEFAULT_LOGGING"] = 'false'
os.environ["CYBER_LOG"] = '/home/ds/custom/config/logformat.json'

# %%
cyber_config = AnalyticsManagerConfig()

# %%
cyber_config.status()
# Out:
# CYBER_ARGS (environment variable) :: /home/ds/custom/config/wh_60m.json
# CYBER_ARGS (config object)        :: /home/ds/custom/config/wh_60m.json
# CYBER_ROOT (environment variable) :: /home/ds
# CYBER_ROOT (config object)        :: /home/ds
# CYBER_DEFAULT_LOGGING (environment variable) :: false
# CYBER_DEFAULT_LOGGING (config object)        :: False
# CYBER_LOG (environment variable) :: /home/ds/custom/config/logformat.json
# CYBER_LOG (config object)        :: /home/ds/custom/config/logformat.json
# analytics_type: sascyber.analytics
# custom_analytics_allowed: True
# custom_analytics_path: /home/ds/custom/wh
# analyticsList: {
#     "Finalizer": [
#         {
#             "support.Finalizer": {
#                 "conn_mandatory": false,
#                 "processed_file": "${myFile}"
#             }
#         }
#     ],
#     "NFLoadTable": [
#         {
#             "support.LoadTable": {
#                 "index_vars": [
#                     "UserName",
#                     "EventID"
#                 ],
#                 "input_caslib": "WH",
#                 "input_file": "${myFile}",
#                 "input_import_options": {
#                     "filetype": "sashdat",
#                     "getnames": "false",
#                     "stripblanks": "true",
#                     "vars": [
#                         {
#                             "name": "AuthenticationPackage",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Destination",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "DomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "EventID",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "FailureReason",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogHost",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonType",
#                             "type": "double"
#                         },
#                         {
#                             "name": "LogonTypeDescription",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ServiceName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Source",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Status",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectDomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectLogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectUserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Time",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "UserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "occurredTime",
#                             "type": "varchar"
#                         }
#                     ]
#                 }
#             }
#         }
#     ],
#     "ResolveEventsFailedLogins": [
#         {
#             "support.ResolveFilters": {
#                 "filter": "EventsFailedLogins",
#                 "index_vars": [
#                     "UserName",
#                     "EventID"
#                 ],
#                 "input_caslib": "WH",
#                 "input_file": "${myFile}",
#                 "input_import_options": {
#                     "filetype": "sashdat",
#                     "getnames": "false",
#                     "stripblanks": "true",
#                     "vars": [
#                         {
#                             "name": "AuthenticationPackage",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Destination",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "DomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "EventID",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "FailureReason",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogHost",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonType",
#                             "type": "double"
#                         },
#                         {
#                             "name": "LogonTypeDescription",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ServiceName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Source",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Status",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectDomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectLogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectUserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Time",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "UserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "occurredTime",
#                             "type": "varchar"
#                         }
#                     ]
#                 }
#             }
#         }
#     ],
#     "WindowsHostFailedLoginsAnalytic": [
#         {
#             "whFailedLogins": {
#                 "cleanup": true,
#                 "comparison_fields": [],
#                 "event_type_id": 2801101,
#                 "filter": "EventsFailedLogins",
#                 "input_caslib": "WH",
#                 "input_file": "${myFile}",
#                 "input_import_options": {
#                     "filetype": "sashdat",
#                     "getnames": "false",
#                     "stripblanks": "true",
#                     "vars": [
#                         {
#                             "name": "AuthenticationPackage",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Destination",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "DomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "EventID",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "FailureReason",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogHost",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "LogonType",
#                             "type": "double"
#                         },
#                         {
#                             "name": "LogonTypeDescription",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ParentProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ProcessName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "ServiceName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Source",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Status",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectDomainName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectLogonID",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "SubjectUserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "Time",
#                             "type": "int64"
#                         },
#                         {
#                             "name": "UserName",
#                             "type": "varchar"
#                         },
#                         {
#                             "name": "occurredTime",
#                             "type": "varchar"
#                         }
#                     ]
#                 },
#                 "threshold": 0.9
#             }
#         }
#     ]
# }
# filters: {
#     "EventsFailedLogins": {
#         "clause": "EventID = 4625",
#         "input": "{intable}",
#         "output": "{intable}_FAILED_LOGINS"
#     }
# }
# loginfo: {
#     "formatters": {
#         "f": {
#             "datefmt": "%Y-%m-%d::%H:%M:%S",
#             "format": "%(asctime)s:\t%(process)d:\t%(filename)s:\t%(levelname)s:\t[%(name)s:%(filename)s:%(lineno)s - %(funcName)s()] %(message)s"
#         }
#     },
#     "handlers": {
#         "h": {
#             "class": "logging.StreamHandler",
#             "formatter": "f",
#             "level": "DEBUG",
#             "stream": "ext://sys.stdout"
#         },
#         "h2": {
#             "class": "logging.FileHandler",
#             "filename": "/home/ds/logs/sascyber_timing.log",
#             "formatter": "f",
#             "level": "INFO"
#         },
#         "h3": {
#             "class": "logging.FileHandler",
#             "filename": "/home/ds/logs/sascyber.log",
#             "formatter": "f",
#             "level": "DEBUG"
#         }
#     },
#     "loggers": {
#         "sascyber": {
#             "handlers": [
#                 "h3"
#             ],
#             "level": "DEBUG",
#             "propagate": false
#         },
#         "timing": {
#             "handlers": [
#                 "h2"
#             ],
#             "level": "INFO",
#             "propagate": false
#         }
#     },
#     "version": 1
# }

# %%
os.chdir(cyber_config.CYBER_ROOT)

# %%
log = setup_logging(cyber_config)
log.info("initialization successful")

# %%
server = DAGServer(cyber_config)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-a7a65b6ac206> in <module>
# ----> 1 server = DAGServer(cyber_config)
#
# ~/code/Analysis.AnalyticsModule/sascyber/utils/decorators.py in timed(*args, **kwargs)
#      35     def timed(*args, **kwargs):
#      36         ts = time.time()
# ---> 37         result = method(*args, **kwargs)
#      38         te = time.time()
#      39
#
# ~/code/Analysis.AnalyticsModule/sascyber/servers/DAGServer.py in __init__(self, config)
#      29         analytics_list = config.get_analytics_list()
#      30
# ---> 31         analytics_names = [analytic_name for index in range(len(analytics_list))
#      32                            for analytic_name in analytics_list[index].keys()
#      33                            if 'enabled' not in analytics_list[index][analytic_name] or
#
# ~/code/Analysis.AnalyticsModule/sascyber/servers/DAGServer.py in <listcomp>(.0)
#      30
#      31         analytics_names = [analytic_name for index in range(len(analytics_list))
# ---> 32                            for analytic_name in analytics_list[index].keys()
#      33                            if 'enabled' not in analytics_list[index][analytic_name] or
#      34                            analytics_list[index][analytic_name]['enabled']]
#
# KeyError: 0
